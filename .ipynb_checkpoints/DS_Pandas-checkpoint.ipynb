# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
import expectexception

# %% [markdown]
# # Pandas
#
# <!-- requirement: data/yelp.json.gz -->
# <!-- requirement: data/PEP_2016_PEPANNRES.csv -->

# %%
import pandas as pd

# %% [markdown]
# We introduced the Pandas module and the DataFrame object in the lesson on [basic data science modules](DS_Basic_DS_Modules.ipynb). We learned how to construct a DataFrame, add data, retrieve data, and [basic reading and writing to disk](DS_IO.ipynb). Now we'll explore the DataFrame object and its powerful analysis methods in more depth.
#
# We'll work with a data set from the online review site, Yelp. The file is stored as a compressed JSON file.

# %%
# !ls -lh ./data/yelp.json.gz
# Out:
# -rw-rw-r-- 1 jovyan users 4.2M Apr 13 15:58 ./data/yelp.json.gz

# %%
import gzip
import simplejson as json

with gzip.open('./data/yelp.json.gz', 'r') as f:
    yelp_data = [json.loads(line) for line in f]

yelp_df = pd.DataFrame(yelp_data)
yelp_df.head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %% [markdown]
# ## Pandas DataFrame and Series
#
# The Pandas DataFrame is a highly structured object. Each row corresponds with some physical entity or event. We think of all of the information in a given row as referring to one object (e.g. a business). Each column contains one type of data, both semantically (e.g. names, counts of reviews, star ratings) and syntactically.

# %%
yelp_df.dtypes
# Out:
# attributes        object
# business_id       object
# categories        object
# city              object
# full_address      object
# hours             object
# latitude         float64
# longitude        float64
# name              object
# neighborhoods     object
# open                bool
# review_count       int64
# stars            float64
# state             object
# type              object
# dtype: object

# %% [markdown]
# We can reference the columns by name, like we would with a `dict`.

# %%
yelp_df['city'].head()
# Out:
# 0      Phoenix
# 1    De Forest
# 2    De Forest
# 3    De Forest
# 4    De Forest
# Name: city, dtype: object

# %%
type(yelp_df['city'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# An individual column is a Pandas `Series`. A `Series` has a `name` and a `dtype` (similar to a NumPy array). A `DataFrame` is essentially a `dict` of `Series` objects. The `Series` has an `index` attribute, which label the rows. The index is essentially a set of keys for referencing the rows. We can have an index composed of numbers, strings, timestamps, or any hashable Python object. The index will also have homogeneous type.

# %%
yelp_df['city'].index
# Out:
# RangeIndex(start=0, stop=37938, step=1)

# %% [markdown]
# The `DataFrame` has an `index` given by the union of indices of its constituent `Series` (we'll explore this later in more detail). Since a `DataFrame` is a `dict` of `Series`, we can select a column and then a row using square bracket notation, but not the reverse (however, the `loc` method works around this).

# %%
# this works
yelp_df['city'][100]
# Out:
# 'Madison'

# %%
# %%expect_exception KeyError
#
# # this doesn't
# yelp_df[100]['city']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 100
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-a719463eea94> in <module>()
#       1
#       2 # this doesn't
# ----> 3 yelp_df[100]['city']
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 100

# %%
yelp_df.loc[100, 'city']
# Out:
# 'Madison'

# %% [markdown]
# Understanding the underlying structure of the `DataFrame` object as a `dict` of `Series` will help you avoid errors and help you think about how the `DataFrame` should behave when we begin doing more complicated analysis.
#
# We can _aggregate_ data in a `DataFrame` using methods like `mean`, `sum`, `count`, and `std`. To view a collection of summary statistics for each column we can use the `describe` method.

# %%
yelp_df.describe()
# Out:
#            latitude     longitude  review_count         stars
# count  37938.000000  37938.000000  37938.000000  37938.000000
# mean      36.530288   -104.097172     29.300648      3.672914
# std        5.822588     28.365375     92.893064      0.888730
# min       32.876638   -115.369725      3.000000      1.000000
# 25%       33.476739   -115.136389      4.000000      3.000000
# 50%       33.680247   -112.068820      8.000000      3.500000
# 75%       36.141875   -111.883274     21.000000      4.500000
# max       56.033777     -3.050088   4084.000000      5.000000

# %% [markdown]
# The utility of a DataFrame comes from its ability to split data into groups, using the `groupby` method, and then perform custom aggregations using the `apply` or `aggregate` method. This process of splitting the data into groups, applying an aggregation, and then collecting the results is [discussed in detail in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/groupby.html), and is one of the main focuses of this notebook.

# %% [markdown]
# ## DataFrame construction
#
# Since a `DataFrame` is a `dict` of `Series`, the natural way to construct a `DataFrame` is to use a `dict` of `Series`-like objects.

# %%
from string import ascii_letters, digits
import numpy as np
import datetime

# %%
usernames = ['alice36', 'bob_smith', 'eve']

passwords = [''.join(np.random.choice(list(ascii_letters + digits), 8)) for x in range(3)]
creation_dates = [datetime.datetime.now().date() - datetime.timedelta(int(x)) for x in np.random.randint(0, 1500, 3)]

# %%
df = pd.DataFrame({'username': usernames, 'password': passwords, 'date-created': pd.to_datetime(creation_dates)})
df
# Out:
#   date-created  password   username
# 0   2015-08-28  BjnmKmAE    alice36
# 1   2017-02-12  AUHMnrcM  bob_smith
# 2   2016-12-16  H5l1RkG0        eve

# %%
df.dtypes
# Out:
# date-created    datetime64[ns]
# password                object
# username                object
# dtype: object

# %% [markdown]
# The `DataFrame` is also closely related to the NumPy `ndarray`.

# %%
random_data = np.random.random((4,3))
random_data
# Out:
# array([[0.91394198, 0.28403593, 0.48339726],
#        [0.9409563 , 0.50724751, 0.47466724],
#        [0.71928486, 0.94464337, 0.77715151],
#        [0.52643601, 0.60411114, 0.61612777]])

# %%
df_random = pd.DataFrame(random_data, columns=['a', 'b', 'c'])
df_random
# Out:
#           a         b         c
# 0  0.913942  0.284036  0.483397
# 1  0.940956  0.507248  0.474667
# 2  0.719285  0.944643  0.777152
# 3  0.526436  0.604111  0.616128

# %% [markdown]
# To add a new column or row, we simply use `dict`-like assignment.

# %%
emails = ['alice.chan@gmail.com', 'bwsmith1983@gmail.com', 'fakemail123@yahoo.com']
df['email'] = emails
df
# Out:
#   date-created  password   username                  email
# 0   2015-08-28  BjnmKmAE    alice36   alice.chan@gmail.com
# 1   2017-02-12  AUHMnrcM  bob_smith  bwsmith1983@gmail.com
# 2   2016-12-16  H5l1RkG0        eve  fakemail123@yahoo.com

# %%
# loc references index value, NOT position
# for position use iloc
df.loc[3] = ['2015-01-29', '38uzFJ1n', 'melvintherobot', 'moviesrgood@moviesrgood.com']
df
# Out:
#           date-created  password        username                        email
# 0  2015-08-28 00:00:00  BjnmKmAE         alice36         alice.chan@gmail.com
# 1  2017-02-12 00:00:00  AUHMnrcM       bob_smith        bwsmith1983@gmail.com
# 2  2016-12-16 00:00:00  H5l1RkG0             eve        fakemail123@yahoo.com
# 3           2015-01-29  38uzFJ1n  melvintherobot  moviesrgood@moviesrgood.com

# %% [markdown]
# We can also drop columns and rows.

# %%
df.drop(3)
# Out:
#           date-created  password   username                  email
# 0  2015-08-28 00:00:00  BjnmKmAE    alice36   alice.chan@gmail.com
# 1  2017-02-12 00:00:00  AUHMnrcM  bob_smith  bwsmith1983@gmail.com
# 2  2016-12-16 00:00:00  H5l1RkG0        eve  fakemail123@yahoo.com

# %%
# to drop a column, need axis=1
df.drop('email', axis=1)
# Out:
#           date-created  password        username
# 0  2015-08-28 00:00:00  BjnmKmAE         alice36
# 1  2017-02-12 00:00:00  AUHMnrcM       bob_smith
# 2  2016-12-16 00:00:00  H5l1RkG0             eve
# 3           2015-01-29  38uzFJ1n  melvintherobot

# %% [markdown]
# Notice when we dropped the `'email'` column, the row at index 3 was in the `DataFrame`, even though we just dropped it! Most operations in Pandas return a _copy_ of the `DataFrame`, rather than modifying the `DataFrame` object itself. Therefore, in order to permanently alter the `DataFrame`, we either need to reassign the `df` variable, or use the `inplace` keyword.

# %%
df.drop(3, inplace=True)
df
# Out:
#           date-created  password   username                  email
# 0  2015-08-28 00:00:00  BjnmKmAE    alice36   alice.chan@gmail.com
# 1  2017-02-12 00:00:00  AUHMnrcM  bob_smith  bwsmith1983@gmail.com
# 2  2016-12-16 00:00:00  H5l1RkG0        eve  fakemail123@yahoo.com

# %% [markdown]
# Since the `index` and column names are important for interacting with data in the DataFrame, we should make sure to set them to useful values. We can do this during construction or after.

# %%
df = pd.DataFrame({'email': emails, 'password': passwords, 'date-created': creation_dates}, index=usernames)
df.index.name = 'username' # it can be helpful to give the index a name
df
# Out:
#           date-created                  email  password
# username
# alice36     2015-08-28   alice.chan@gmail.com  BjnmKmAE
# bob_smith   2017-02-12  bwsmith1983@gmail.com  AUHMnrcM
# eve         2016-12-16  fakemail123@yahoo.com  H5l1RkG0

# %%
# alternatively
df = pd.DataFrame(list(zip(usernames, emails, passwords, creation_dates)))
df
# Out:
#            0                      1         2           3
# 0    alice36   alice.chan@gmail.com  BjnmKmAE  2015-08-28
# 1  bob_smith  bwsmith1983@gmail.com  AUHMnrcM  2017-02-12
# 2        eve  fakemail123@yahoo.com  H5l1RkG0  2016-12-16

# %%
df.columns = ['username', 'email', 'password', 'date-created']
df.set_index('username', inplace=True)
df
# Out:
#                            email  password date-created
# username
# alice36     alice.chan@gmail.com  BjnmKmAE   2015-08-28
# bob_smith  bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# eve        fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %%
# to reset index to a column
df.reset_index(inplace=True)
df
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  BjnmKmAE   2015-08-28
# 1  bob_smith  bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# 2        eve  fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %% [markdown]
# We can have multiple levels to an index. We'll discover that for some data sets it is necessary to have multiple levels to the index in order to uniquely identify a row.

# %%
df.set_index(['username', 'email'])
# Out:
#                                  password date-created
# username  email
# alice36   alice.chan@gmail.com   BjnmKmAE   2015-08-28
# bob_smith bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# eve       fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %% [markdown]
# ### Reading data from file
#
# We can also construct a DataFrame using data stored in a file or received from a website. The data source might be [JSON](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_json.html), [HTML](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html), [CSV](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html#pandas.read_csv), [Excel](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html), [Python pickle](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_pickle.html), or even a [database connection](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql.html). Each format will have its own methods for reading and writing data that take different arguments. The arguments of these methods usually depend on the particular formatting of the file. For example, the values in a CSV might be separate by commas or semi-colons, it might have a header or it might not.
#
# The `read_csv` method has to deal with the most formatting possibilities, so we will explore that method with a few examples. Try to apply these ideas when working with other file formats, but keep in mind that each format and read method is different. Always check [the Pandas documentation](http://pandas.pydata.org/pandas-docs/stable/io.html) when having trouble with reading or writing data.

# %%
csv = [','.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
with open('./data/read_csv_example.csv', 'w') as f:
    [f.write(line + '\n') for line in csv]

# !cat ./data/read_csv_example.csv
# Out:
# username,email,password,date-created
# alice36,alice.chan@gmail.com,BjnmKmAE,2015-08-28
# bob_smith,bwsmith1983@gmail.com,AUHMnrcM,2017-02-12
# eve,fakemail123@yahoo.com,H5l1RkG0,2016-12-16

# %%
pd.read_csv('./data/read_csv_example.csv')
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  BjnmKmAE   2015-08-28
# 1  bob_smith  bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# 2        eve  fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %%
# we can also set an index from the data
pd.read_csv('./data/read_csv_example.csv', index_col=0)
# Out:
#                            email  password date-created
# username
# alice36     alice.chan@gmail.com  BjnmKmAE   2015-08-28
# bob_smith  bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# eve        fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %%
# what if our data had no header?
with open('./data/read_csv_noheader_example.csv', 'w') as f:
    [f.write(line + '\n') for i, line in enumerate(csv) if i != 0]
    
# !cat ./data/read_csv_noheader_example.csv
# Out:
# alice36,alice.chan@gmail.com,BjnmKmAE,2015-08-28
# bob_smith,bwsmith1983@gmail.com,AUHMnrcM,2017-02-12
# eve,fakemail123@yahoo.com,H5l1RkG0,2016-12-16

# %%
pd.read_csv('./data/read_csv_noheader_example.csv', names=['username', 'email', 'password', 'date-created'], header=None)
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  BjnmKmAE   2015-08-28
# 1  bob_smith  bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# 2        eve  fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %%
# what if our data was tab-delimited?
tsv = ['\t'.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
with open('./data/read_csv_example.tsv', 'w') as f:
    [f.write(line + '\n') for line in tsv]

# !cat ./data/read_csv_example.tsv
# Out:
# username	email	password	date-created
# alice36	alice.chan@gmail.com	BjnmKmAE	2015-08-28
# bob_smith	bwsmith1983@gmail.com	AUHMnrcM	2017-02-12
# eve	fakemail123@yahoo.com	H5l1RkG0	2016-12-16

# %%
pd.read_csv('./data/read_csv_example.tsv', delimiter='\t')
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  BjnmKmAE   2015-08-28
# 1  bob_smith  bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# 2        eve  fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %% [markdown]
# Even within a single file format, data can be arranged and formatted in many ways. These have been just a few examples of the kinds of arguments you might need to use with `read_csv` in order to read data into a DataFrame in an organized way.

# %% [markdown]
# ## Filtering DataFrames
#
# One of the powerful analytical tools of the Pandas DataFrame is its syntax for filtering data. Often we'll only want to work with a certain subset of our data based on some criteria. Let's look at our Yelp data for an example.

# %%
yelp_df.head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %% [markdown]
# We see the Yelp data set has a `'state'` column. If we are only interested in businesses in Arizona (AZ), we can filter the DataFrame and select only that data.

# %%
az_yelp_df = yelp_df[yelp_df['state'] == 'AZ']
az_yelp_df.head()
# Out:
#                                             attributes  \
# 0                        {'By Appointment Only': True}
# 297  {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...
# 298  {'Take-out': True, 'Noise Level': 'quiet', 'De...
# 299  {'Alcohol': 'full_bar', 'Price Range': 1, 'Noi...
# 300  {'Price Range': 2, 'Alcohol': 'full_bar', 'Goo...
#
#                 business_id  \
# 0    vcNAWiLM4dR7D2nwwJ7nCA
# 297  x5Mv61CnZLohZWxfCVCPTQ
# 298  2ZnCITVa0abGce4gZ6RhIw
# 299  EmzaQR5hQlF0WIl24NxAZA
# 300  SiwN7f0N4bs4ZtPc4yPgiA
#
#                                             categories     city  \
# 0                          [Doctors, Health & Medical]  Phoenix
# 297    [Sandwiches, Pizza, Chicken Wings, Restaurants]  Phoenix
# 298          [American (New), Sandwiches, Restaurants]  Phoenix
# 299  [American (New), Nightlife, Dance Clubs, Resta...  Phoenix
# 300                           [Nightlife, Dance Clubs]  Phoenix
#
#                                           full_address  \
# 0    4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 297              2819 N Central Ave\nPhoenix, AZ 85004
# 298              1850 N Central Ave\nPhoenix, AZ 85004
# 299             132 E Washington St\nPhoenix, AZ 85004
# 300               710 N Central Ave\nPhoenix, AZ 85004
#
#                                                  hours   latitude   longitude  \
# 0    {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 297                                                 {}  33.479542 -112.073418
# 298                                                 {}  33.468988 -112.074315
# 299  {'Sunday': {'close': '02:00', 'open': '21:00'}...  33.448399 -112.071702
# 300                                                 {}  33.456068 -112.074225
#
#                        name neighborhoods  open  review_count  stars state  \
# 0         Eric Goldberg, MD            []  True             7    3.5    AZ
# 297          Domino's Pizza            []  True            12    2.5    AZ
# 298  Viad Tower Restaurants            []  True             5    3.5    AZ
# 299              Sky Lounge            []  True            20    2.5    AZ
# 300                 Palazzo            []  True            15    2.5    AZ
#
#          type
# 0    business
# 297  business
# 298  business
# 299  business
# 300  business

# %%
az_yelp_df['state'].unique()
# Out:
# array(['AZ'], dtype=object)

# %% [markdown]
# We can combine criteria using logic. What if we're only interested in businesses with more than 10 reviews in Arizona?

# %%
yelp_df[(yelp_df['state'] == 'AZ') & (yelp_df['review_count'] > 10)].head()
# Out:
#                                             attributes  \
# 297  {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...
# 299  {'Alcohol': 'full_bar', 'Price Range': 1, 'Noi...
# 300  {'Price Range': 2, 'Alcohol': 'full_bar', 'Goo...
# 301                                                 {}
# 302  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
#
#                 business_id  \
# 297  x5Mv61CnZLohZWxfCVCPTQ
# 299  EmzaQR5hQlF0WIl24NxAZA
# 300  SiwN7f0N4bs4ZtPc4yPgiA
# 301  M-MFa0YErVBbFW2IJhGJmw
# 302  KPoTixdjoJxSqRSEApSAGg
#
#                                             categories     city  \
# 297    [Sandwiches, Pizza, Chicken Wings, Restaurants]  Phoenix
# 299  [American (New), Nightlife, Dance Clubs, Resta...  Phoenix
# 300                           [Nightlife, Dance Clubs]  Phoenix
# 301  [Auto Repair, Automotive, Tires, Oil Change St...  Phoenix
# 302                                [Thai, Restaurants]  Phoenix
#
#                                full_address  \
# 297   2819 N Central Ave\nPhoenix, AZ 85004
# 299  132 E Washington St\nPhoenix, AZ 85004
# 300    710 N Central Ave\nPhoenix, AZ 85004
# 301   386 E Virginia Ave\nPhoenix, AZ 85004
# 302   2631 N Central Ave\nPhoenix, AZ 85004
#
#                                                  hours   latitude   longitude  \
# 297                                                 {}  33.479542 -112.073418
# 299  {'Sunday': {'close': '02:00', 'open': '21:00'}...  33.448399 -112.071702
# 300                                                 {}  33.456068 -112.074225
# 301  {'Tuesday': {'close': '18:00', 'open': '07:30'...  33.476784 -112.065806
# 302  {'Monday': {'close': '21:00', 'open': '11:00'}...  33.477934 -112.073524
#
#                       name neighborhoods  open  review_count  stars state  \
# 297         Domino's Pizza            []  True            12    2.5    AZ
# 299             Sky Lounge            []  True            20    2.5    AZ
# 300                Palazzo            []  True            15    2.5    AZ
# 301  Virginia Auto Service            []  True            28    4.0    AZ
# 302           Wild Thaiger            []  True           281    4.0    AZ
#
#          type
# 297  business
# 299  business
# 300  business
# 301  business
# 302  business

# %% [markdown]
# How does this filtering work?
#
# When we write `yelp_df['state'] == 'AZ'`, Pandas selects the `'state'` column and checks whether each row is `'AZ'`. If so, that row is marked `True`, and if not, it is marked `False`. This is how we would normally expect a conditional to work, only now applied to an entire Pandas `Series`. We end up with a Pandas `Series` of Boolean variables.

# %%
(yelp_df['state'] == 'AZ').head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: state, dtype: bool

# %% [markdown]
# We can use a `Series` (or any similar object) of Boolean variables to index the DataFrame.

# %%
df
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  BjnmKmAE   2015-08-28
# 1  bob_smith  bwsmith1983@gmail.com  AUHMnrcM   2017-02-12
# 2        eve  fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %%
df[[True, False, True]]
# Out:
#   username                  email  password date-created
# 0  alice36   alice.chan@gmail.com  BjnmKmAE   2015-08-28
# 2      eve  fakemail123@yahoo.com  H5l1RkG0   2016-12-16

# %% [markdown]
# This let's us filter a DataFrame using idiomatic logical expressions like `yelp_df['review_count'] > 10`.
#
# As another example, let's consider the `'open'` column, which is a `True`/`False` flag for whether a business is open. This is also a Boolean Pandas `Series`, so we can just use it directly.

# %%
# the open businesses
yelp_df[yelp_df['open']].head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %%
# the closed businesses
yelp_df[~yelp_df['open']].head()
# Out:
#                                            attributes             business_id  \
# 5                                                  {}  oLctHIA1AxmsgOuu4dM6Vw
# 14  {'Take-out': True, 'Caters': True, 'Attire': '...  HxPpZSY6Q1eARuiahhra6A
# 16  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  77ESrCo7hQ96VpCWWdvoxg
# 50  {'Alcohol': 'full_bar', 'Attire': 'casual', 'P...  IEmqrFe96NOhU07TA0rZdw
# 62  {'By Appointment Only': True, 'Parking': {'gar...  mbtGl2I2A2To-8jiggN99g
#
#                                            categories        city  \
# 5                   [Television Stations, Mass Media]  Mc Farland
# 14  [Event Planning & Services, Party & Event Plan...   Middleton
# 16                             [Mexican, Restaurants]   Middleton
# 50              [American (Traditional), Restaurants]   Middleton
# 62            [Skin Care, Hair Salons, Beauty & Spas]   Middleton
#
#                                          full_address  \
# 5              4156 County Rd B\nMc Farland, WI 53558
# 14           6401 University Ave\nMiddleton, WI 53562
# 16           6230 University Ave\nMiddleton, WI 53562
# 50              6625 Century Ave\nMiddleton, WI 53562
# 62  6661 University Ave\nSte 103\nMiddleton, WI 53562
#
#                                                 hours   latitude  longitude  \
# 5                                                  {}  42.968507 -89.322920
# 14                                                 {}  43.093265 -89.491800
# 16  {'Monday': {'close': '21:00', 'open': '06:00'}...  43.091061 -89.487487
# 50                                                 {}  43.104535 -89.494422
# 62  {'Tuesday': {'close': '20:00', 'open': '10:00'...  43.096650 -89.497265
#
#                               name neighborhoods   open  review_count  stars  \
# 5           Charter Communications            []  False            10    1.5
# 14   Crandalls Carryout & Catering            []  False             5    4.0
# 16                       Mi Cocina            []  False            17    3.0
# 50  Stamm House At Pheasant Branch            []  False             7    2.0
# 62                         Tangles            []  False             7    2.0
#
#    state      type
# 5     WI  business
# 14    WI  business
# 16    WI  business
# 50    WI  business
# 62    WI  business

# %% [markdown]
# Notice in an earlier expression we wrote `(yelp_df['state'] == 'AZ') & (yelp_df['review_count'] > 10)`. Normally in Python we use the word `and` when we are working with logic. In Pandas we have to use _bit-wise_ logical operators; all that's important to know is the following equivalencies:
#
# `~` = `not`
# `&` = `and`
# `|` = `or`
#
# We can also use Panda's built-in [string operations](https://pandas.pydata.org/pandas-docs/stable/text.html) for doing pattern matching. For example, there are a lot of businesses in Las Vegas in our data set. However, there are also businesses in 'Las Vegas East' and 'South Las Vegas'. To get all of the Las Vegas businesses I might do the following.

# %%
vegas_yelp_df = yelp_df[yelp_df['city'].str.contains('Vegas')]
vegas_yelp_df.head()
# Out:
#                                              attributes  \
# 4348  {'Parking': {'garage': False, 'street': False,...
# 4360  {'Parking': {'garage': True, 'street': False, ...
# 4364  {'By Appointment Only': False, 'Parking': {'ga...
# 4441  {'Alcohol': 'full_bar', 'Music': {'video': Fal...
# 4489                                                 {}
#
#                  business_id  \
# 4348  uzztTCsg3XAKlYqmLO40aw
# 4360  IspFZDcpu9W5NvvJ7QgJZg
# 4364  Dvulg9cc3XHkt5DkBUekhw
# 4441  _SM8UKIwBNbmj1r629ipoQ
# 4489  Zaw0IAXwopKX4MV23MHQRw
#
#                                              categories       city  \
# 4348  [Arts & Entertainment, Shopping, Books, Mags, ...  Las Vegas
# 4360  [Women's Clothing, Men's Clothing, Fashion, Sh...  Las Vegas
# 4364                       [Hair Salons, Beauty & Spas]  Las Vegas
# 4441  [Wine Bars, Bars, Restaurants, Nightlife, Ital...  Las Vegas
# 4489                             [Car Wash, Automotive]  Las Vegas
#
#                                            full_address  \
# 4348  5835 S Eastern Ave\nSoutheast\nLas Vegas, NV 8...
# 4360  The Forum Shops At Caesars\n3500 Las Vegas Blv...
# 4364  467 E Silverado Ranch Blvd\nSte 175\nSoutheast...
# 4441  1916 Village Center Cir\nSummerlin\nLas Vegas,...
# 4489  2718 E Tropicana Avenue\nEastside\nLas Vegas, ...
#
#                                                   hours   latitude  \
# 4348  {'Monday': {'close': '21:00', 'open': '10:00'}...  36.083936
# 4360  {'Monday': {'close': '21:00', 'open': '10:00'}...  36.124423
# 4364                                                 {}  36.012150
# 4441  {'Monday': {'close': '23:00', 'open': '11:00'}...  36.192414
# 4489                                                 {}  36.100507
#
#        longitude                    name          neighborhoods   open  \
# 4348 -115.119422  Psychic Eye Book Shops            [Southeast]   True
# 4360 -115.146372                     Gap             [Eastside]   True
# 4364 -115.153303             Great Clips            [Southeast]   True
# 4441 -115.304396            Chianti Cafe            [Summerlin]  False
# 4489 -115.113492         Terrible Herbst  [Eastside, Southeast]   True
#
#       review_count  stars state      type
# 4348             7    4.5    NV  business
# 4360             6    4.5    NV  business
# 4364            10    2.5    NV  business
# 4441             9    3.5    NV  business
# 4489             3    1.5    NV  business

# %%
vegas_yelp_df['city'].unique()
# Out:
# array(['Las Vegas', 'North Las Vegas', 'N Las Vegas', 'N. Las Vegas',
#        'C Las Vegas', 'Las Vegas ', 'Las Vegas, NV 89147',
#        'Las Vegas East', 'North Las Vegas ', 'N E Las Vegas',
#        'N W Las Vegas', 'Lake Las Vegas', 'South Las Vegas'], dtype=object)

# %% [markdown]
# ## Applying functions and data aggregation
#
# To analyze the data in the dataframe, we'll need to be able to apply functions to it. Pandas has many mathematical functions built in already, and DataFrames and Series can be passed to NumPy functions (since they behave like NumPy arrays).

# %%
log_review_count = np.log(yelp_df['review_count'])
print(log_review_count.head())
print(log_review_count.shape)
# Out:
# 0    1.945910
# 1    3.258097
# 2    2.772589
# 3    1.945910
# 4    1.098612
# Name: review_count, dtype: float64
# (37938,)

# %%
mean_review_count = yelp_df['review_count'].mean()
print(mean_review_count)
# Out:
# 29.300648426379883

# %% [markdown]
# In the first example we took the _logarithm_ of the review count for each business. In the second case, we calculated the mean review count of all businesses. In the first case, we ended up with a number for each business. We _transformed_ the review counts using the logarithm. In the second case, we _summarized_ the review counts of all the businesses in one number. This summary is a form of _data aggregation_, in which we take many data points and combine them into some smaller representation. The functions we apply to our data sets will either be in the category of **transformations** or **aggregations**.
#
# Sometimes we will need to transform our data in order for it to be usable. For instance, in the `'attributes'` column of our DataFrame, we have a `dict` for each business listing all of its properties. If I wanted to find a restaurant that offers delivery service, it would be difficult for me to filter the DataFrame, even though that information is in the `'attributes'` column. First, I need to transform the `dict` into something more useful.

# %%
def get_delivery_attr(attr_dict):
    return attr_dict.get('Delivery')

# %% [markdown]
# If we give this function a `dict` from the `'attributes'` column, it will look for the `'Delivery'` key. If it finds that key, it returns the value. If it doesn't find the key, it will return none.

# %%
print(get_delivery_attr(yelp_df.loc[0, 'attributes']))
print(get_delivery_attr(yelp_df.loc[1, 'attributes']))
print(get_delivery_attr(yelp_df.loc[2, 'attributes']))
# Out:
# None
# False
# False

# %% [markdown]
# We could iterate over the rows of `yelp_df['attributes']` to get all of the values, but there is a better way. DataFrames and Series have an `apply` method that allows us to apply our function to the entire data set at once, like we did earlier with `np.log`.

# %%
delivery_attr = yelp_df['attributes'].apply(get_delivery_attr)
delivery_attr.head()
# Out:
# 0     None
# 1    False
# 2    False
# 3    False
# 4     None
# Name: attributes, dtype: object

# %% [markdown]
# We can make a new column in our DataFrame with this transformed (and useful) information.

# %% [markdown]
# ### yelp_df['delivery'] = delivery_attr
#
# # to find businesses that deliver
# yelp_df[yelp_df['delivery'].fillna(False)].head()

# %% [markdown]
# It's less common (though possible) to use `apply` on an entire DataFrame rather than just one column. Since a DataFrame might contain many types of data, we won't usually want to apply the same transformation or aggregation across all of the columns.

# %% [markdown]
# ## Data aggregation with `groupby`
#
# Data aggregation is an [_overloaded_](https://en.wikipedia.org/wiki/Function_overloading) term. It refers to both data summarization (as above) but also to the combining of different data sets.
#
# With our Yelp data, we might be interested in comparing the star ratings of businesses in different cities. We could calculate the mean star rating for each city, and this would allow us to easily compare them. First we would have to split up our data by city, calculate the mean for each city, and then combine it back at the end. This procedure is known as [split-apply-combine](https://pandas.pydata.org/pandas-docs/stable/groupby.html) and is a classic example of data aggregation (in the sense of both summarizing data and also combining different data sets).
#
# We achieve the splitting and recombining using the `groupby` method.

# %%
yelp_df
# Out:
#                                               attributes  \
# 0                          {'By Appointment Only': True}
# 1      {'Take-out': True, 'Good For': {'dessert': Fal...
# 2      {'Take-out': True, 'Good For': {'dessert': Fal...
# 3      {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...
# 4      {'Take-out': True, 'Has TV': False, 'Outdoor S...
# 5                                                     {}
# 6                                                     {}
# 7                                      {'Wi-Fi': 'free'}
# 8                                                     {}
# 9      {'Alcohol': 'full_bar', 'Noise Level': 'loud',...
# 10     {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 11                               {'Good for Kids': True}
# 12     {'Take-out': True, 'Good For': {'dessert': Fal...
# 13     {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 14     {'Take-out': True, 'Caters': True, 'Attire': '...
# 15     {'Take-out': True, 'Good For': {'dessert': Fal...
# 16     {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 17                               {'Good for Kids': True}
# 18      {'Accepts Credit Cards': True, 'Price Range': 2}
# 19     {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 20     {'By Appointment Only': False, 'Good for Kids'...
# 21     {'Take-out': True, 'Takes Reservations': False...
# 22     {'Parking': {'garage': False, 'street': False,...
# 23     {'Parking': {'garage': False, 'street': True, ...
# 24     {'Parking': {'garage': False, 'street': True, ...
# 25     {'Wi-Fi': 'free', 'Price Range': 1, 'Outdoor S...
# 26     {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 27     {'Good For': {'dessert': False, 'latenight': F...
# 28     {'Take-out': True, 'Good For': {'dessert': Fal...
# 29     {'Take-out': True, 'Takes Reservations': False...
# ...                                                  ...
# 37908                     {'Accepts Credit Cards': True}
# 37909  {'Take-out': False, 'Good For': {'dessert': Fa...
# 37910   {'Accepts Credit Cards': True, 'Price Range': 2}
# 37911  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37912                                                 {}
# 37913  {'Has TV': False, 'Good For Groups': True, 'Ou...
# 37914  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37915  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37916  {'Parking': {'garage': False, 'street': False,...
# 37917  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37918                     {'Accepts Credit Cards': True}
# 37919  {'Parking': {'garage': False, 'street': False,...
# 37920                     {'Accepts Credit Cards': True}
# 37921  {'Parking': {'garage': False, 'street': False,...
# 37922  {'Parking': {'garage': False, 'street': False,...
# 37923  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37924  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37925   {'Accepts Credit Cards': True, 'Price Range': 2}
# 37926  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37927                            {'Good for Kids': True}
# 37928  {'Take-out': False, 'Wi-Fi': 'free', 'Drive-Th...
# 37929  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37930  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37931  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37932  {'Alcohol': 'full_bar', 'Noise Level': 'quiet'...
# 37933  {'Alcohol': 'none', 'Good For Dancing': True, ...
# 37934                                                 {}
# 37935                           {'Good for Kids': False}
# 37936  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37937  {'Parking': {'garage': False, 'street': False,...
#
#                   business_id  \
# 0      vcNAWiLM4dR7D2nwwJ7nCA
# 1      JwUE5GmEO-sH1FuwJgKBlQ
# 2      uGykseHzyS5xAMWoN6YUqA
# 3      LRKJF43s9-3jG9Lgx4zODg
# 4      RgDg-k9S5YD_BaxMckifkg
# 5      oLctHIA1AxmsgOuu4dM6Vw
# 6      ZW2WeP2Hp20tq0RG1NFkoQ
# 7      95p9Xg358BezJyk1wqzzyg
# 8      ZlhAvs_6ryi4_efZ1SpMbg
# 9      _wZTYYL7cutanzAnJUTGMA
# 10     XrzTVrJAjs0yYLvhFI9vkQ
# 11     1tkeiIa-daD8LbM6mHm_9A
# 12     zOc8lbjViUZajbY7M0aUCQ
# 13     UgjVZTSOaYoEvws_lAP_Dw
# 14     HxPpZSY6Q1eARuiahhra6A
# 15     SKLw05kEIlZcpTD5pqma8Q
# 16     77ESrCo7hQ96VpCWWdvoxg
# 17     368m5-RtrrYWf4hPM_bMlg
# 18     YjoSdr8uJslIebsQP6c18w
# 19     rKNtd_M2kWDW8sQKYzetKA
# 20     x7xS2DJvu8klyNzcpN8QHg
# 21     KTqNU4plO23583DYAMGXYg
# 22     cgCqxPhadIAlsqnD1MoWuQ
# 23     YDUB7-NgjKEFn8CERLoKXQ
# 24     x7pStpT09Tdc8d7oRU0Tmw
# 25     1-EIdeHewfEVcpoZm38N8A
# 26     ShEYKerTwb2LSORE5o_s7A
# 27     HaBkx5PwvbBpQ2iNCgHnVQ
# 28     KW6HejC-67KSL9J8Cz1dSw
# 29     wl-7A4jC0f27MOEmW-XTbQ
# ...                       ...
# 37908  uV2EhAuAmPDxZOlIgAGFxw
# 37909  aybLDQRhUwOr7WoQfdofPQ
# 37910  l48YFfpkcTEh0mvSG9wfLA
# 37911  fmfiSDAJtjxbnRBBtYhnNw
# 37912  pOz8fQ1Y8fP3C4ARE9TG_w
# 37913  xT1MO7MLMp3jK4XT1LXiKA
# 37914  51vtDjP79vBjaI5dbkPoPw
# 37915  F8ZrWvngdHYnKrALwZAdBw
# 37916  NRjz0_SjSqNbIoXWGnlp7w
# 37917  0EXVIF07vw-QTTy9V7-ebg
# 37918  jTUe25wOiM0ZtP9Ba7i8VQ
# 37919  pU88U9_yEUVfpox30VBWPg
# 37920  k6CRXdN7GMMNQ4VJUOEzbg
# 37921  0Nwda6h7mRhiQBbxi0xhhw
# 37922  qZkW6s0qxtUTrjWw_0je-g
# 37923  8K4pWvuJmGWXDgCugYKYvw
# 37924  wmm19sGdCiL5IZhViYQY2Q
# 37925  flhtNfzfGiySc3g_U0Zkeg
# 37926  5se9c1ggSm2oMrnWO3ZSgw
# 37927  UH4BReVAqpMVjyVroEJAGA
# 37928  EYpqqsJZ3L2EFAPK-NEOFA
# 37929  KN-3Sg8TZ-y67026TFwmjw
# 37930  ZpB2O-WAbbRHdP0V8GrwXA
# 37931  OEUIE8VBa1BbBfr5EPcTOA
# 37932  yZXEELxi8KMwzXCHP345GQ
# 37933  iyKyJoDcbkGrMCgvyfMHxw
# 37934  tsvWY4o64xiv7K0VA89R8A
# 37935  nYer89hXYAoddMEKTxw7kA
# 37936  BMjggIgOghBMEXPo8q7q3w
# 37937  BVxlrYWgmi-8TPGMe6CTpg
#
#                                               categories         city  \
# 0                            [Doctors, Health & Medical]      Phoenix
# 1                                          [Restaurants]    De Forest
# 2                  [American (Traditional), Restaurants]    De Forest
# 3      [Food, Ice Cream & Frozen Yogurt, Fast Food, R...    De Forest
# 4                                 [Chinese, Restaurants]    De Forest
# 5                      [Television Stations, Mass Media]   Mc Farland
# 6       [Home Services, Heating & Air Conditioning/HVAC]   Mc Farland
# 7              [Libraries, Public Services & Government]   Mc Farland
# 8                                  [Veterinarians, Pets]   Mc Farland
# 9      [Bars, American (Traditional), Nightlife, Loun...   Mc Farland
# 10     [Hotels & Travel, Bed & Breakfast, Event Plann...   Mc Farland
# 11                                [Active Life, Bowling]   Mc Farland
# 12                                  [Pizza, Restaurants]   Mc Farland
# 13                                [Chinese, Restaurants]   Mc Farland
# 14     [Event Planning & Services, Party & Event Plan...    Middleton
# 15     [Party & Event Planning, Asian Fusion, Event P...    Middleton
# 16                                [Mexican, Restaurants]    Middleton
# 17     [Active Life, Arts & Entertainment, Stadiums &...    Middleton
# 18                                  [Pet Services, Pets]    Middleton
# 19     [Hotels & Travel, Event Planning & Services, V...    Middleton
# 20     [Pilates, Yoga, Weight Loss Centers, Health & ...    Middleton
# 21       [Sandwiches, Pizza, Chicken Wings, Restaurants]    Middleton
# 22     [Shopping, Arts & Crafts, Event Planning & Ser...    Middleton
# 23     [Arts & Crafts, Shopping, Knitting Supplies, H...    Middleton
# 24     [Women's Clothing, Shopping Centers, Fashion, ...    Middleton
# 25            [Food, Beer, Wine & Spirits, Coffee & Tea]    Middleton
# 26     [Bakeries, Food, Breakfast & Brunch, Coffee & ...    Middleton
# 27        [Bars, American (New), Nightlife, Restaurants]    Middleton
# 28                                [Chinese, Restaurants]    Middleton
# 29                                [Chinese, Restaurants]    Middleton
# ...                                                  ...          ...
# 37908  [Local Services, Data Recovery, Mobile Phone R...    Las Vegas
# 37909                         [Steakhouses, Restaurants]      Madison
# 37910        [Shopping, Home & Garden, Furniture Stores]      Gilbert
# 37911        [American (New), Comfort Food, Restaurants]  Sun Prairie
# 37912            [Arts & Entertainment, Performing Arts]    Las Vegas
# 37913                          [Tapas Bars, Restaurants]    Edinburgh
# 37914                               [Pizza, Restaurants]      Phoenix
# 37915  [Food, Tea Rooms, Coffee & Tea, Asian Fusion, ...     Waterloo
# 37916   [Used, Vintage & Consignment, Fashion, Shopping]   Scottsdale
# 37917                               [Cafes, Restaurants]  Queen Creek
# 37918                            [Movers, Home Services]      Phoenix
# 37919                                   [Bakeries, Food]    Henderson
# 37920                          [Handyman, Home Services]  Queen Creek
# 37921                                 [Food, Shaved Ice]     Avondale
# 37922                             [Food, Specialty Food]    Las Vegas
# 37923                          [Sushi Bars, Restaurants]   Scottsdale
# 37924                          [Vietnamese, Restaurants]    Las Vegas
# 37925               [Food, Desserts, Cupcakes, Bakeries]    Las Vegas
# 37926                            [Filipino, Restaurants]    Las Vegas
# 37927                     [Active Life, Amusement Parks]    Henderson
# 37928                             [Burgers, Restaurants]    Edinburgh
# 37929                       [Chicken Wings, Restaurants]    Las Vegas
# 37930                      [American (New), Restaurants]    Henderson
# 37931  [Food, Juice Bars & Smoothies, American (New),...    Henderson
# 37932  [Bars, Turkish, Mediterranean, Nightlife, Loun...    Las Vegas
# 37933            [Bars, Hookah Bars, Nightlife, Lounges]     Glendale
# 37934  [Active Life, Barre Classes, Pilates, Fitness ...      Madison
# 37935                        [Yelp Events, Local Flavor]      Phoenix
# 37936              [Kosher, Italian, Pizza, Restaurants]      Phoenix
# 37937       [Food, Ethnic Food, Grocery, Specialty Food]    Edinburgh
#
#                                             full_address  \
# 0      4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1                6162 US Highway 51\nDe Forest, WI 53532
# 2                    505 W North St\nDe Forest, WI 53532
# 3                  4910 County Rd V\nDe Forest, WI 53532
# 4                     631 S Main St\nDe Forest, WI 53532
# 5                 4156 County Rd B\nMc Farland, WI 53558
# 6                 4709 Triangle St\nMc Farland, WI 53558
# 7                  5114 Farwell St\nMc Farland, WI 53558
# 8             4811 Larson Beach Rd\nMc Farland, WI 53558
# 9             4506 Larson Beach Rd\nMc Farland, WI 53558
# 10               5508 Broadhead St\nMc Farland, WI 53558
# 11                 4711 Farwell St\nMc Farland, WI 53558
# 12                    5813 Main St\nMc Farland, WI 53558
# 13            4850 Larson Beach Rd\nMc Farland, WI 53558
# 14              6401 University Ave\nMiddleton, WI 53562
# 15                  2039 Allen Blvd\nMiddleton, WI 53562
# 16              6230 University Ave\nMiddleton, WI 53562
# 17                8312 Forsythia St\nMiddleton, WI 53562
# 18                 8402 Old Sauk Rd\nMiddleton, WI 53562
# 19                 7790 Elmwood Ave\nMiddleton, WI 53562
# 20                  2529 Allen Blvd\nMiddleton, WI 53562
# 21                  2411 Allen Blvd\nMiddleton, WI 53562
# 22                  1661 Deming Way\nMiddleton, WI 53562
# 23                  1700 Deming Way\nMiddleton, WI 53562
# 24                  1620 Deming Way\nMiddleton, WI 53562
# 25                   1901 Cayuga St\nMiddleton, WI 53562
# 26      6720 Frank Lloyd Wright Ave\nMiddleton, WI 53562
# 27                2401 Parmenter St\nMiddleton, WI 53562
# 28                 8414 Old Sauk Rd\nMiddleton, WI 53562
# 29                  2608 Allen Blvd\nMiddleton, WI 53562
# ...                                                  ...
# 37908  1033 S Rainbow Blvd\nWestside\nLas Vegas, NV 8...
# 37909        14 W Mifflin St\nCapitol\nMadison, WI 53703
# 37910     2757 S San Tan Village Pkwy\nGilbert, AZ 85295
# 37911  2804 Prairie Lakes Dr\nSte 106\nSun Prairie, W...
# 37912  83 Panorama Crest Ave\nSouth Summerlin\nLas Ve...
# 37913           297 Leith Walk\nLeith\nEdinburgh EH6 8SA
# 37914               1031 NW Grand Ave\nPhoenix, AZ 85007
# 37915                255 King Street N\nWaterloo, ON N2J
# 37916         1312 N Scottsdale Rd\nScottsdale, AZ 85257
# 37917  22721 S Ellsworth Rd\nSte 107\nQueen Creek, AZ...
# 37918         1816 E Oak St\nSte 4566\nPhoenix, AZ 85006
# 37919  10251 S Eastern Ave\nSte C\nAnthem\nHenderson,...
# 37920                              Queen Creek, AZ 85142
# 37921  13045 W Rancho Santa Fe Blvd\nA105\nAvondale, ...
# 37922  3700 S Hualapai Way\nSte 108\nSouth Summerlin\...
# 37923             4320 N Miller Rd\nScottsdale, AZ 85251
# 37924  4860 W Desert Inn Rd\nSte 9\nWestside\nLas Veg...
# 37925                     Southeast\nLas Vegas, NV 89120
# 37926     6820 W Flamingo Rd\nSte A\nLas Vegas, NV 89103
# 37927               900 Galleria Dr\nHenderson, NV 89011
# 37928       45 Broughton St\nNew Town\nEdinburgh EH1 3JU
# 37929  6475 W Charleston Blvd\nSte 150\nWestside\nLas...
# 37930  140 S Green Valley Pkwy\nSte 142\nHenderson, N...
# 37931        19 S Stephanie\nSte140\nHenderson, NV 89012
# 37932  2550 S Rainbow Blvd\nSte  W1\nWestside\nLas Ve...
# 37933          4340 W Thunderbird Rd\nGlendale, AZ 85306
# 37934  1 E Main St\nLower Level Suite 5\nCapitol\nMad...
# 37935           FilmBar\n815 N 2nd St\nPhoenix, AZ 85004
# 37936                   6505 N 7th St\nPhoenix, AZ 85014
# 37937     125 Lauriston Pl\nTollcross\nEdinburgh EH3 9JN
#
#                                                    hours   latitude  \
# 0      {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313
# 1                                                     {}  43.238893
# 2      {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267
# 3      {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045
# 4      {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875
# 5                                                     {}  42.968507
# 6                                                     {}  43.030356
# 7      {'Monday': {'close': '20:00', 'open': '09:00'}...  43.014093
# 8      {'Monday': {'close': '18:00', 'open': '07:30'}...  43.017124
# 9                                                     {}  43.017701
# 10                                                    {}  43.015931
# 11     {'Monday': {'close': '02:00', 'open': '11:00'}...  43.013156
# 12     {'Tuesday': {'close': '22:00', 'open': '16:30'...  43.014164
# 13                                                    {}  43.017939
# 14                                                    {}  43.093265
# 15     {'Monday': {'close': '14:00', 'open': '11:00'}...  43.090642
# 16     {'Monday': {'close': '21:00', 'open': '06:00'}...  43.091061
# 17     {'Monday': {'close': '21:00', 'open': '09:00'}...  43.110157
# 18                                                    {}  43.077415
# 19                                                    {}  43.096271
# 20     {'Monday': {'close': '00:00', 'open': '00:00'}...  43.103072
# 21                                                    {}  43.100384
# 22     {'Monday': {'close': '21:00', 'open': '09:30'}...  43.095498
# 23     {'Monday': {'close': '21:00', 'open': '09:00'}...  43.092903
# 24     {'Monday': {'close': '20:00', 'open': '10:00'}...  43.091816
# 25     {'Monday': {'close': '21:00', 'open': '06:00'}...  43.096359
# 26     {'Monday': {'close': '15:00', 'open': '07:00'}...  43.107227
# 27     {'Monday': {'close': '11:00', 'open': '07:00'}...  43.101460
# 28     {'Monday': {'close': '21:00', 'open': '11:00'}...  43.075345
# 29     {'Monday': {'close': '22:00', 'open': '11:00'}...  43.103663
# ...                                                  ...        ...
# 37908  {'Monday': {'close': '19:00', 'open': '10:00'}...  36.159549
# 37909                                                 {}  43.075200
# 37910  {'Monday': {'close': '19:00', 'open': '10:00'}...  33.308632
# 37911                                                 {}  43.166396
# 37912                                                 {}  36.121936
# 37913                                                 {}  55.964986
# 37914  {'Tuesday': {'close': '04:00', 'open': '20:00'...  33.454960
# 37915                                                 {}  43.477274
# 37916  {'Monday': {'close': '21:00', 'open': '10:00'}...  33.462616
# 37917  {'Monday': {'close': '16:00', 'open': '07:00'}...  33.241852
# 37918  {'Monday': {'close': '20:00', 'open': '07:00'}...  33.464409
# 37919  {'Monday': {'close': '16:30', 'open': '06:00'}...  36.003386
# 37920                                                 {}  33.248664
# 37921  {'Monday': {'close': '21:00', 'open': '11:00'}...  33.460467
# 37922  {'Monday': {'close': '21:00', 'open': '10:00'}...  36.121962
# 37923  {'Monday': {'close': '21:30', 'open': '17:00'}...  33.499192
# 37924  {'Monday': {'close': '22:00', 'open': '11:00'}...  36.129992
# 37925  {'Monday': {'close': '17:00', 'open': '09:00'}...  36.083335
# 37926  {'Monday': {'close': '22:00', 'open': '10:00'}...  36.114987
# 37927                                                 {}  36.070909
# 37928  {'Tuesday': {'close': '21:30', 'open': '12:00'...  55.957536
# 37929  {'Monday': {'close': '20:00', 'open': '11:00'}...  36.158604
# 37930                                                 {}  36.022463
# 37931  {'Monday': {'close': '20:00', 'open': '08:00'}...  36.028049
# 37932  {'Monday': {'close': '22:00', 'open': '11:00'}...  36.143397
# 37933  {'Monday': {'close': '02:00', 'open': '18:00'}...  33.610822
# 37934                                                 {}  43.073871
# 37935                                                 {}  33.457106
# 37936  {'Monday': {'close': '21:00', 'open': '11:00'}...  33.531310
# 37937                                                 {}  55.944170
#
#         longitude                                               name  \
# 0     -111.983758                                  Eric Goldberg, MD
# 1      -89.335844                               Pine Cone Restaurant
# 2      -89.353437                         Deforest Family Restaurant
# 3      -89.374983                                           Culver's
# 4      -89.343722                        Chang Jiang Chinese Kitchen
# 5      -89.322920                             Charter Communications
# 6      -89.298544                                Air Quality Systems
# 7      -89.294175                           McFarland Public Library
# 8      -89.299119                            Spartan Animal Hospital
# 9      -89.303789                    Beach House Restaurant & Lounge
# 10     -89.285206                      Parsonage Bed & Breakfast the
# 11     -89.302164                                       Spartan Bowl
# 12     -89.288567                                      Spartan Pizza
# 13     -89.298628                       Main Moon Chinese Restaurant
# 14     -89.491800                      Crandalls Carryout & Catering
# 15     -89.485169                 Imperial Garden Chinese Restaurant
# 16     -89.487487                                          Mi Cocina
# 17     -89.526428                                 Keva Sports Center
# 18     -89.527273                               Wild Birds Unlimited
# 19     -89.516038  Staybridge Suites Extended Stay Hotel Middleto...
# 20     -89.486082                               Harbor Athletic Club
# 21     -89.486219                                     Domino's Pizza
# 22     -89.523525                                          Archivers
# 23     -89.527703                                           Michaels
# 24     -89.528450                   Greenway Station Shopping Center
# 25     -89.513737                           Barriques Wine & Spirits
# 26     -89.496995                              Prairie Cafe & Bakery
# 27     -89.511162                            Paul's Neighborhood Bar
# 28     -89.528480                                  Chin's Asia Fresh
# 29     -89.486491                             Grand China Restaurant
# ...           ...                                                ...
# 37908 -115.245389                                  My Computer Bytes
# 37909  -89.385835                                    Rare Steakhouse
# 37910 -111.746902                                At Home Furnishings
# 37911  -89.270095                                               MACS
# 37912 -115.344752                                     Water Beauties
# 37913   -3.176367                                   Serrano Manchego
# 37914 -112.087116                         Grand Avenue Pizza Company
# 37915  -80.525499                                            Chatime
# 37916 -111.926974                                     Plato's Closet
# 37917 -111.634005                             The Bistro Queen Creek
# 37918 -112.064650                        Movers Phoenix Professional
# 37919 -115.110455                                 Pink Box Doughnuts
# 37920 -111.634299                                  A-1 Hand Handyman
# 37921 -112.336565                                     Zoni Shave Ice
# 37922 -115.314146                        Popped Gourmet Popcorn Spot
# 37923 -111.917816                                            Sushi J
# 37924 -115.207404                                            Pho Lan
# 37925 -115.099975                                           Bakeshop
# 37926 -115.241094                                     D' Pinoy Joint
# 37927 -115.024682                           Cowabunga Bay-Water Park
# 37928   -3.188413                                   Burger Meats Bun
# 37929 -115.236715                                      702 Wing Spot
# 37930 -115.083362                                       LYFE Kitchen
# 37931 -115.048825                                        Presto Cafe
# 37932 -115.241975                  Maza Mediterranean Grill & Lounge
# 37933 -112.152529                                       The V Lounge
# 37934  -89.382842                                    Pilates Central
# 37935 -112.071074              Yelp's Secret Cinema: Made In Arizona
# 37936 -112.064508                    LaBella Pizzeria and Restaurant
# 37937   -3.202529                               Oriental Supermarket
#
#                           neighborhoods   open  review_count  stars state  \
# 0                                    []   True             7    3.5    AZ
# 1                                    []   True            26    4.0    WI
# 2                                    []   True            16    4.0    WI
# 3                                    []   True             7    4.5    WI
# 4                                    []   True             3    4.0    WI
# 5                                    []  False            10    1.5    WI
# 6                                    []   True             4    2.0    WI
# 7                                    []   True             4    2.5    WI
# 8                                    []   True             3    4.5    WI
# 9                                    []   True            31    3.5    WI
# 10                                   []   True             9    5.0    WI
# 11                                   []   True             3    1.5    WI
# 12                                   []   True             4    3.5    WI
# 13                                   []   True             8    3.5    WI
# 14                                   []  False             5    4.0    WI
# 15                                   []   True            41    3.0    WI
# 16                                   []  False            17    3.0    WI
# 17                                   []   True             3    3.5    WI
# 18                                   []   True             3    4.5    WI
# 19                                   []   True             6    4.5    WI
# 20                                   []   True             5    5.0    WI
# 21                                   []   True             3    3.0    WI
# 22                                   []   True             4    3.0    WI
# 23                                   []   True             3    4.0    WI
# 24                                   []   True             7    3.5    WI
# 25                                   []   True            22    4.0    WI
# 26                                   []   True            38    3.5    WI
# 27                                   []   True            11    3.5    WI
# 28                                   []   True            28    3.0    WI
# 29                                   []   True             6    3.0    WI
# ...                                 ...    ...           ...    ...   ...
# 37908                        [Westside]   True             3    4.5    NV
# 37909                         [Capitol]   True             7    3.5    WI
# 37910                                []   True             4    5.0    AZ
# 37911                                []   True             7    3.5    WI
# 37912                 [South Summerlin]   True             5    5.0    NV
# 37913                           [Leith]   True             4    2.5   MLN
# 37914                                []   True             6    4.0    AZ
# 37915                                []   True             6    4.0    ON
# 37916                                []   True             5    1.5    AZ
# 37917                                []   True             5    5.0    AZ
# 37918                                []   True             8    5.0    AZ
# 37919                          [Anthem]   True            12    3.5    NV
# 37920                                []   True             3    5.0    AZ
# 37921                                []   True             5    5.0    AZ
# 37922  [South Summerlin, Spring Valley]   True             3    4.5    NV
# 37923                                []   True            15    4.5    AZ
# 37924                        [Westside]   True            12    4.5    NV
# 37925                       [Southeast]   True             4    5.0    NV
# 37926                                []   True             9    4.0    NV
# 37927                                []   True            26    3.5    NV
# 37928                        [New Town]   True             6    3.5   MLN
# 37929                        [Westside]   True             9    4.5    NV
# 37930                                []   True            34    3.5    NV
# 37931                                []   True            27    4.5    NV
# 37932                        [Westside]   True            18    4.5    NV
# 37933                                []   True             4    5.0    AZ
# 37934                         [Capitol]   True             3    5.0    WI
# 37935                                []   True            17    5.0    AZ
# 37936                                []   True             5    5.0    AZ
# 37937             [Tollcross, Old Town]   True             7    3.5   EDH
#
#            type
# 0      business
# 1      business
# 2      business
# 3      business
# 4      business
# 5      business
# 6      business
# 7      business
# 8      business
# 9      business
# 10     business
# 11     business
# 12     business
# 13     business
# 14     business
# 15     business
# 16     business
# 17     business
# 18     business
# 19     business
# 20     business
# 21     business
# 22     business
# 23     business
# 24     business
# 25     business
# 26     business
# 27     business
# 28     business
# 29     business
# ...         ...
# 37908  business
# 37909  business
# 37910  business
# 37911  business
# 37912  business
# 37913  business
# 37914  business
# 37915  business
# 37916  business
# 37917  business
# 37918  business
# 37919  business
# 37920  business
# 37921  business
# 37922  business
# 37923  business
# 37924  business
# 37925  business
# 37926  business
# 37927  business
# 37928  business
# 37929  business
# 37930  business
# 37931  business
# 37932  business
# 37933  business
# 37934  business
# 37935  business
# 37936  business
# 37937  business
#
# [37938 rows x 15 columns]

# %%
stars_by_city = yelp_df.groupby('city')['stars'].mean()
stars_by_city.head()
# Out:
# city
# Ahwatukee          3.687500
# Anthem             3.781818
# Apache Junction    3.637500
# Arcadia            5.000000
# Atlanta            3.500000
# Name: stars, dtype: float64

# %% [markdown]
# We can also apply multiple functions at once. It might be helpful to know the standard deviation of star ratings, the total number of reviews, and the count of businesses as well.

# %%
agg_by_city = yelp_df.groupby('city').agg({'stars': {'mean': 'mean', 'std': 'std'}, 'review_count': 'sum', 'business_id': 'count'})
agg_by_city.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                     stars           review_count business_id
#                      mean       std          sum       count
# city
# Ahwatukee        3.687500  1.066955          258           8
# Anthem           3.781818  0.756231          727          55
# Apache Junction  3.637500  1.028010          853          80
# Arcadia          5.000000       NaN            4           1
# Atlanta          3.500000       NaN           16           1

# %%
# unstacking the columns
new_columns = map(lambda x: '_'.join(x),
                  zip(agg_by_city.columns.get_level_values(0),
                      agg_by_city.columns.get_level_values(1)))
agg_by_city.columns = new_columns
agg_by_city.head()
# Out:
#                  stars_mean  stars_std  review_count_sum  business_id_count
# city
# Ahwatukee          3.687500   1.066955               258                  8
# Anthem             3.781818   0.756231               727                 55
# Apache Junction    3.637500   1.028010               853                 80
# Arcadia            5.000000        NaN                 4                  1
# Atlanta            3.500000        NaN                16                  1

# %% [markdown]
# How does this work? What does `groupby` do? Let's start by inspecting the result of `groupby`.

# %%
by_city = yelp_df.groupby('city')
by_city

# %%
dir(by_city)
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_add_numeric_operations',
#  '_agg_doc',
#  '_aggregate',
#  '_aggregate_generic',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_block_agg_axis',
#  '_builtin_table',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_blocks',
#  '_cython_agg_general',
#  '_cython_table',
#  '_cython_transform',
#  '_decide_output_index',
#  '_def_str',
#  '_define_paths',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_data_to_aggregate',
#  '_get_index',
#  '_get_indices',
#  '_gotitem',
#  '_group_selection',
#  '_index_with_as_index',
#  '_insert_inaxis_grouper_inplace',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cython_func',
#  '_iterate_column_groupbys',
#  '_iterate_slices',
#  '_make_wrapper',
#  '_obj_with_exclusions',
#  '_post_process_cython_aggregate',
#  '_python_agg_general',
#  '_python_apply_general',
#  '_reindex_output',
#  '_reset_cache',
#  '_reset_group_selection',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_set_group_selection',
#  '_set_result_index_ordered',
#  '_shallow_copy',
#  '_transform_fast',
#  '_transform_general',
#  '_transform_item_by_item',
#  '_try_aggregate_string_function',
#  '_try_cast',
#  '_wrap_agged_blocks',
#  '_wrap_aggregated_output',
#  '_wrap_applied_output',
#  '_wrap_generic_output',
#  '_wrap_transformed_output',
#  'agg',
#  'aggregate',
#  'all',
#  'any',
#  'apply',
#  'attributes',
#  'backfill',
#  'bfill',
#  'boxplot',
#  'business_id',
#  'categories',
#  'city',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cumcount',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'dtypes',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'full_address',
#  'get_group',
#  'groups',
#  'head',
#  'hist',
#  'hours',
#  'idxmax',
#  'idxmin',
#  'indices',
#  'last',
#  'latitude',
#  'longitude',
#  'mad',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'name',
#  'ndim',
#  'neighborhoods',
#  'ngroup',
#  'ngroups',
#  'nth',
#  'nunique',
#  'ohlc',
#  'open',
#  'pad',
#  'pct_change',
#  'plot',
#  'prod',
#  'quantile',
#  'rank',
#  'resample',
#  'review_count',
#  'rolling',
#  'sem',
#  'shift',
#  'size',
#  'skew',
#  'stars',
#  'state',
#  'std',
#  'sum',
#  'tail',
#  'take',
#  'transform',
#  'tshift',
#  'type',
#  'var']

# %%
print(type(by_city.groups))
list(by_city.groups.items())[:5]
# Out:
# <class 'dict'>
# [('Ahwatukee',
#   Int64Index([1718, 1740, 13572, 17787, 20361, 22856, 28608, 30499], dtype='int64')),
#  ('Anthem',
#   Int64Index([ 1946,  1948,  1949,  1950,  1951,  1952,  1953,  1954,  1955,
#                1956,  1957,  1958,  1961,  1962, 11455, 12008, 12572, 12870,
#               13007, 13069, 13286, 13500, 13636, 13703, 13744, 13827, 13935,
#               15483, 15581, 15756, 19358, 21295, 21303, 21327, 22354, 22428,
#               22654, 22782, 23215, 24937, 25026, 26116, 26300, 26331, 26841,
#               26937, 30039, 30170, 31565, 32525, 33027, 33492, 33983, 34663,
#               35433],
#              dtype='int64')),
#  ('Apache Junction',
#   Int64Index([ 2392,  2393,  2394,  2395,  2396,  2397,  2398,  2399,  2400,
#                2401,  2402,  2403,  2404,  2406,  2407,  2408,  2409,  2410,
#                2412,  2413,  2414,  2415,  2417,  2418,  2419,  7305,  7524,
#                7525,  7528,  7529,  7530,  7531,  7532,  7533,  7534, 10813,
#               11315, 11660, 12662, 12858, 12893, 13021, 13107, 13367, 13534,
#               13871, 15645, 17769, 19447, 19682, 19695, 20030, 20977, 21940,
#               22571, 22750, 22884, 23175, 23226, 23429, 25839, 26064, 26169,
#               26582, 27131, 27594, 27901, 28112, 28124, 29329, 30062, 30753,
#               30810, 30850, 31841, 33347, 33378, 34415, 34558, 36436],
#              dtype='int64')),
#  ('Arcadia', Int64Index([20625], dtype='int64')),
#  ('Atlanta', Int64Index([16976], dtype='int64'))]

# %%
type(by_city.get_group('Anthem').head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# When we use `groupby` on a column, Pandas builds a `dict`, using the unique elements of the column as the keys and the index of the rows in each group as the values. This `dict` is stored in the `groups` attribute. Pandas can then use this `dict` to direct the application of aggregating functions over the different groups.

# %% [markdown]
# ## Sorting
#
# Even though the DataFrame in many ways behaves similarly to a `dict`, it also is ordered. Therefore we can sort the data in it. Pandas provides two sorting methods, `sort_values` and `sort_index`.

# %%
yelp_df.sort_values('stars').head()
# Out:
#       attributes             business_id  \
# 36220         {}  2Q2tZ0yQo25cni0PT2j0Zw
# 27946         {}  cHvL85QIV-L2-YlLOcwlCw
# 36332         {}  e23Sa3FCTaIOSZzJsT8sIQ
# 7488          {}  fZO5Fghc6Q07jU8EROzj6Q
# 3370          {}  JjdjS5n6ILh-d3GeTD6qkA
#
#                                               categories        city  \
# 36220  [Real Estate Services, Property Management, Ho...   Las Vegas
# 27946  [Sporting Goods, Shopping, Golf Equipment, Out...       Tempe
# 36332  [Professional Services, Internet Service Provi...  Scottsdale
# 7488                      [Home Services, Pool Cleaners]        Mesa
# 3370                [Hotels & Travel, Motorcycle Rental]  Scottsdale
#
#                                             full_address  \
# 36220  6420 Spring Mountain Rd\nChinatown\nLas Vegas,...
# 27946         5235 S Kyrene Rd\nSte 106\nTempe, AZ 85283
# 36332       3949 N Drinkwater Blvd\nScottsdale, AZ 85251
# 7488                    2431 E Laurel St\nMesa, AZ 85213
# 3370       15820 N 84th St\nSte 25\nScottsdale, AZ 85260
#
#                                                    hours   latitude  \
# 36220                                                 {}  36.125870
# 27946  {'Monday': {'close': '18:00', 'open': '10:00'}...  33.376734
# 36332                                                 {}  33.493469
# 7488                                                  {}  33.457833
# 3370   {'Monday': {'close': '17:00', 'open': '09:00'}...  33.629858
#
#         longitude                            name neighborhoods  open  \
# 36220 -115.232316     Total Real Eatate of Nevada   [Chinatown]  True
# 27946 -111.945955              Custom Golf Center            []  True
# 36332 -111.921620                       Cox Cable            []  True
# 7488  -111.778212  Foster's Pool Service & Repair            []  True
# 3370  -111.900187               Top Spoke Rentals            []  True
#
#        review_count  stars state      type
# 36220             3    1.0    NV  business
# 27946             3    1.0    AZ  business
# 36332             3    1.0    AZ  business
# 7488              6    1.0    AZ  business
# 3370              3    1.0    AZ  business

# %%
yelp_df.set_index('full_address').sort_index().head()
# Out:
#                                                                                            attributes  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704               {'Accepts Credit Cards': True, 'Parking': {'ga...
# #7 Water Street, Suite B\nHenderson, NV 89015       {'Parking': {'garage': False, 'street': True, ...
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...  {'Alcohol': 'full_bar', 'Good For Dancing': Fa...
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE       {'Coat Check': True, 'Accepts Credit Cards': T...
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE   {'Take-out': False, 'Wi-Fi': 'free', 'Good For...
#
#                                                                business_id  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704               cuDgyPCi1TQ0Yf-reY8koQ
# #7 Water Street, Suite B\nHenderson, NV 89015       7vdBKHejbuZPsNYow7eOBA
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...  4EQEcYHR-aa7jfNA1LsCJA
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE       I0U4MQTiSNdGmpYoNcrimg
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE   55J_rNyR7HW8aDs0zJDiTg
#
#                                                                                            categories  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704               [Books, Mags, Music & Video, Shopping, Booksto...
# #7 Water Street, Suite B\nHenderson, NV 89015                                        [Bakeries, Food]
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...                            [Pubs, Bars, Nightlife]
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE                                [Nightlife, Dance Clubs]
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE                          [Steakhouses, Restaurants]
#
#                                                          city  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704                 Madison
# #7 Water Street, Suite B\nHenderson, NV 89015       Henderson
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...  Edinburgh
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE       Edinburgh
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE   Edinburgh
#
#                                                                                                 hours  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704                                                              {}
# #7 Water Street, Suite B\nHenderson, NV 89015       {'Monday': {'close': '17:00', 'open': '07:00'}...
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...  {'Monday': {'close': '00:00', 'open': '11:00'}...
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE       {'Monday': {'close': '03:00', 'open': '20:00'}...
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE   {'Monday': {'close': '22:00', 'open': '12:00'}...
#
#                                                      latitude   longitude  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704               43.127954  -89.304327
# #7 Water Street, Suite B\nHenderson, NV 89015       36.035933 -114.985882
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...  55.958954   -3.197945
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE       55.950030   -3.207645
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE   55.949445   -3.208475
#
#                                                                          name  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704                          Barnes & Noble
# #7 Water Street, Suite B\nHenderson, NV 89015       Chef Flemming's Bake Shop
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...         The Cumberland Bar
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE                   The One Below
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE    Kyloe Restaurant & Grill
#
#                                                            neighborhoods  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704                                 []
# #7 Water Street, Suite B\nHenderson, NV 89015                         []
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...            [New Town]
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE       [West End, New Town]
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE             [West End]
#
#                                                     open  review_count  stars  \
# full_address
# #1 East Towne Mall\nMadison, WI 53704               True             3    3.5
# #7 Water Street, Suite B\nHenderson, NV 89015       True            84    4.5
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...  True            22    4.5
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE       True             3    3.0
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE   True            25    4.0
#
#                                                    state      type
# full_address
# #1 East Towne Mall\nMadison, WI 53704                 WI  business
# #7 Water Street, Suite B\nHenderson, NV 89015         NV  business
# 1 - 3 Cumberland Street\nNew Town\nEdinburgh EH...   EDH  business
# 1 - 3 Rutland St\nWest End\nEdinburgh EH1 2AE        EDH  business
# 1 - 3 Rutland Street\nWest End\nEdinburgh EH1 2AE    EDH  business

# %% [markdown]
# Don't forget that most Pandas operations return a copy of the DataFrame, and do not update the DataFrame in place (unless we tell it to)!

# %% [markdown]
# ## Joining data sets

# %% [markdown]
# Often we will want to augment one data set with data from another. For instance, businesses in big cities probably get more reviews than those in small cities. It could be useful to scale the review counts by the city's population. To do that, we'll need to add population data to the Yelp data. We can get population data from the US census.

# %%
census = pd.read_csv('./data/PEP_2016_PEPANNRES.csv', skiprows=[1])

census.head()
# Out:
#                 GEO.id    GEO.id2  \
# 0  0610000US0900104720  900104720
# 1  0610000US0900108070  900108070
# 2  0610000US0900108980  900108980
# 3  0610000US0900118500  900118500
# 4  0610000US0900118850  900118850
#
#                                 GEO.display-label  rescen42010  resbase42010  \
# 0      Bethel town, Fairfield County, Connecticut      18584.0         18584
# 1  Bridgeport town, Fairfield County, Connecticut     144229.0        144236
# 2  Brookfield town, Fairfield County, Connecticut      16452.0         16452
# 3     Danbury town, Fairfield County, Connecticut      80893.0         80903
# 4      Darien town, Fairfield County, Connecticut      20732.0         20732
#
#    respop72010  respop72011  respop72012  respop72013  respop72014  \
# 0        18642        18942        19150        19267        19316
# 1       144912       146226       146962       147666       147560
# 2        16483        16635        16785        16859        17016
# 3        81356        82182        82788        83678        83687
# 4        20777        20975        21127        21342        21641
#
#    respop72015  respop72016
# 0        19463        19627
# 1       147090       145936
# 2        17087        17098
# 3        84236        84992
# 4        21718        21744

# %%
# construct city & state fields
census['city'] = census['GEO.display-label'].apply(lambda x: x.split(', ')[0])
census['state'] = census['GEO.display-label'].apply(lambda x: x.split(', ')[2])

# %%
# convert state names to abbreviations

print(census['state'].unique())
# Out:
# ['Connecticut' 'Illinois' 'Indiana' 'Kansas' 'Maine' 'Massachusetts'
#  'Michigan' 'Minnesota' 'Missouri' 'Nebraska' 'New Hampshire' 'New Jersey'
#  'New York' 'North Dakota' 'Ohio' 'Pennsylvania' 'Rhode Island'
#  'South Dakota' 'Vermont' 'Wisconsin']

# %%
state_abbr = dict(zip(census['state'].unique(), ['CT', 'IL', 'IN', 'KS', 'ME', 'MA', 'MI', 'MN', 'MO', 'NE', 'NH', 'NJ', 'NY', 'ND', 'OH', 'PA', 'RI', 'SD', 'VT', 'WI']))
state_abbr
# Out:
# {'Connecticut': 'CT',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Kansas': 'KS',
#  'Maine': 'ME',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Missouri': 'MO',
#  'Nebraska': 'NE',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New York': 'NY',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Dakota': 'SD',
#  'Vermont': 'VT',
#  'Wisconsin': 'WI'}

# %%
census['state'] = census['state'].replace(state_abbr)

# %%
# remove last word (e.g. 'city', 'town', township', 'borough', 'village') from city names

census['city'] = census['city'].apply(lambda x: ' '.join(x.split(' ')[:-1]))

# %%
merged_df = yelp_df.merge(census, on=['state', 'city'])
merged_df.head()
# Out:
#                                           attributes             business_id  \
# 0  {'Take-out': True, 'Caters': True, 'Attire': '...  HxPpZSY6Q1eARuiahhra6A
# 1  {'Take-out': True, 'Caters': True, 'Attire': '...  HxPpZSY6Q1eARuiahhra6A
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  SKLw05kEIlZcpTD5pqma8Q
# 3  {'Take-out': True, 'Good For': {'dessert': Fal...  SKLw05kEIlZcpTD5pqma8Q
# 4  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  77ESrCo7hQ96VpCWWdvoxg
#
#                                           categories       city  \
# 0  [Event Planning & Services, Party & Event Plan...  Middleton
# 1  [Event Planning & Services, Party & Event Plan...  Middleton
# 2  [Party & Event Planning, Asian Fusion, Event P...  Middleton
# 3  [Party & Event Planning, Asian Fusion, Event P...  Middleton
# 4                             [Mexican, Restaurants]  Middleton
#
#                                full_address  \
# 0  6401 University Ave\nMiddleton, WI 53562
# 1  6401 University Ave\nMiddleton, WI 53562
# 2      2039 Allen Blvd\nMiddleton, WI 53562
# 3      2039 Allen Blvd\nMiddleton, WI 53562
# 4  6230 University Ave\nMiddleton, WI 53562
#
#                                                hours   latitude  longitude  \
# 0                                                 {}  43.093265 -89.491800
# 1                                                 {}  43.093265 -89.491800
# 2  {'Monday': {'close': '14:00', 'open': '11:00'}...  43.090642 -89.485169
# 3  {'Monday': {'close': '14:00', 'open': '11:00'}...  43.090642 -89.485169
# 4  {'Monday': {'close': '21:00', 'open': '06:00'}...  43.091061 -89.487487
#
#                                  name neighborhoods     ...       \
# 0       Crandalls Carryout & Catering            []     ...
# 1       Crandalls Carryout & Catering            []     ...
# 2  Imperial Garden Chinese Restaurant            []     ...
# 3  Imperial Garden Chinese Restaurant            []     ...
# 4                           Mi Cocina            []     ...
#
#                         GEO.display-label  rescen42010  resbase42010  \
# 0  Middleton city, Dane County, Wisconsin      17442.0         17558
# 1  Middleton town, Dane County, Wisconsin       5877.0          5831
# 2  Middleton city, Dane County, Wisconsin      17442.0         17558
# 3  Middleton town, Dane County, Wisconsin       5877.0          5831
# 4  Middleton city, Dane County, Wisconsin      17442.0         17558
#
#   respop72010 respop72011 respop72012  respop72013 respop72014  respop72015  \
# 0       17622       17903       18271        18522       18694        18955
# 1        5845        5943        6030         6086        6140         6179
# 2       17622       17903       18271        18522       18694        18955
# 3        5845        5943        6030         6086        6140         6179
# 4       17622       17903       18271        18522       18694        18955
#
#    respop72016
# 0        19109
# 1         6257
# 2        19109
# 3         6257
# 4        19109
#
# [5 rows x 27 columns]

# %% [markdown]
# The `merge` function looks through the `'state'` and `'city'` columns of `yelp_df` and `census` and tries to match up rows that share values. When a match is found, the rows are combined. What happens when a match is not found? We can imagine four scenarios:
#
# 1. We only keep rows from `yelp_df` and `census` if they match. Any rows from either table that have no match are discarded. This is called an _inner join_.
#
# 2. We keep all rows from `yelp_df` and `census`, even if they have no match. In this case, when a row in `yelp_df` has no match in `census`, all the columns from `census` are merged in with null values. When a row in `census` has no match in `yelp_df`, all the columns from `yelp_df` are merged in with null values. This is called an _outer join_.
#
# 3. We privilege the `yelp_df` data. If a row in `yelp_df` has no match in `census`, we keep it and fill in the missing `census` columns as null values. If a row in `census` has no match in `yelp_df`, we discard it. This is called a _left join_.
#
# 4. We privilege the `census` data. This is called a _right join_.
#
# The default behavior for Pandas is case #1, the _inner join_. This means if there are cities in `yelp_df` that we don't have matching `census` data for, they are dropped. Therefore, `merged_df` might be smaller than `yelp_df`.

# %%
print(yelp_df.shape)
print(merged_df.shape)
# Out:
# (37938, 15)
# (3598, 27)

# %% [markdown]
# There are a lot of cities in `yelp_df` that aren't in `census`! We might want to keep these rows, but we don't need any census data where there are no businesses. Then we should use a _left join_.

# %%
merged_df = yelp_df.merge(census, on=['state', 'city'], how='left')
print(yelp_df.shape)
print(merged_df.shape)
# Out:
# (37938, 15)
# (39648, 27)

# %% [markdown]
# Sometimes we don't need to merge together the columns of separate data sets, but just need to add more rows. For example, the New York City subway system [releases data about how many customers enter and exit the station each week](http://web.mta.info/developers/turnstile.html). Each weekly data set has the same columns, so if we want multiple weeks of data, we just have to append one week to another.

# %%
nov18 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171118.txt')
nov11 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171111.txt')

# %%
nov18.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6402636
# 1  REGULAR  6402645
# 2  REGULAR  6402717
# 3  REGULAR  6402857
# 4  REGULAR  6403178
#
#    EXITS
# 0                                            2166100
# 1                                            2166112
# 2                                            2166175
# 3                                            2166230
# 4                                            2166292

# %%
nov11.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6393563
# 1  REGULAR  6393595
# 2  REGULAR  6393616
# 3  REGULAR  6393742
# 4  REGULAR  6394021
#
#    EXITS
# 0                                            2162811
# 1                                            2162822
# 2                                            2162855
# 3                                            2162933
# 4                                            2162992

# %%
nov = pd.concat([nov18, nov11])
nov['DATE'].unique()
# Out:
# array(['11/11/2017', '11/12/2017', '11/13/2017', '11/14/2017',
#        '11/15/2017', '11/16/2017', '11/17/2017', '11/04/2017',
#        '11/05/2017', '11/06/2017', '11/07/2017', '11/08/2017',
#        '11/09/2017', '11/10/2017'], dtype=object)

# %% [markdown]
# We can also use `concat` to perform inner and outer joins based on index. For example, we can perform some data aggregation and then join the results onto the original DataFrame.

# %%
city_counts = yelp_df.groupby('city')['business_id'].count().rename('city_counts')
city_counts.head()
# Out:
# city
# Ahwatukee           8
# Anthem             55
# Apache Junction    80
# Arcadia             1
# Atlanta             1
# Name: city_counts, dtype: int64

# %%
pd.concat([yelp_df.set_index('city'), city_counts], axis=1, join='inner').reset_index().head()
# Out:
#         city                                         attributes  \
# 0    Phoenix                      {'By Appointment Only': True}
# 1  De Forest  {'Take-out': True, 'Good For': {'dessert': Fal...
# 2  De Forest  {'Take-out': True, 'Good For': {'dessert': Fal...
# 3  De Forest  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...
# 4  De Forest  {'Take-out': True, 'Has TV': False, 'Outdoor S...
#
#               business_id                                         categories  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA                        [Doctors, Health & Medical]
# 1  JwUE5GmEO-sH1FuwJgKBlQ                                      [Restaurants]
# 2  uGykseHzyS5xAMWoN6YUqA              [American (Traditional), Restaurants]
# 3  LRKJF43s9-3jG9Lgx4zODg  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...
# 4  RgDg-k9S5YD_BaxMckifkg                             [Chinese, Restaurants]
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type  city_counts
# 0  business         6715
# 1  business            6
# 2  business            6
# 3  business            6
# 4  business            6

# %% [markdown]
# Pandas provides [extensive documentation](https://pandas.pydata.org/pandas-docs/stable/merging.html) with diagrammed examples on different methods and approaches for joining data.

# %% [markdown]
# ## Working with time series
# Pandas has a well-designed backend for inferring dates and times from strings and doing meaningful computations with them.

# %%
pop_growth = pd.read_html('https://web.archive.org/web/20170127165708/https://www.census.gov/population/international/data/worldpop/table_population.php', attrs={'class': 'query_table'}, parse_dates=[0])[0]
pop_growth.dropna(inplace=True)
pop_growth.head()
# Out:
#         Year    Population  Annual Growth Rate (%)  Annual Population Change
# 0 1950-01-01  2.557629e+09                   1.459                37311223.0
# 1 1951-01-01  2.594940e+09                   1.612                41832429.0
# 2 1952-01-01  2.636772e+09                   1.717                45281083.0
# 3 1953-01-01  2.682053e+09                   1.796                48174715.0
# 4 1954-01-01  2.730228e+09                   1.900                51870839.0

# %% [markdown]
# By setting the `'Year'` column to the index, we can easily aggregate data by date using the `resample` method. The `resample` method allows us to decrease or increase the sampling frequency of our data. For instance, maybe instead of yearly data, we want to see average quantities for each decade.

# %%
pop_growth.set_index('Year', inplace=True)
pop_growth
# Out:
#               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-01-01  2.557629e+09                   1.459                37311223.0
# 1951-01-01  2.594940e+09                   1.612                41832429.0
# 1952-01-01  2.636772e+09                   1.717                45281083.0
# 1953-01-01  2.682053e+09                   1.796                48174715.0
# 1954-01-01  2.730228e+09                   1.900                51870839.0
# 1955-01-01  2.782099e+09                   1.912                53200730.0
# 1956-01-01  2.835300e+09                   1.977                56050044.0
# 1957-01-01  2.891350e+09                   1.964                56787531.0
# 1958-01-01  2.948137e+09                   1.783                52579345.0
# 1959-01-01  3.000717e+09                   1.409                42284915.0
# 1960-01-01  3.043002e+09                   1.346                40965421.0
# 1961-01-01  3.083967e+09                   1.820                56126288.0
# 1962-01-01  3.140093e+09                   2.221                69734665.0
# 1963-01-01  3.209828e+09                   2.224                71373424.0
# 1964-01-01  3.281201e+09                   2.110                69224487.0
# 1965-01-01  3.350426e+09                   2.097                70252130.0
# 1966-01-01  3.420678e+09                   2.036                69655792.0
# 1967-01-01  3.490334e+09                   2.062                71980107.0
# 1968-01-01  3.562314e+09                   2.101                74845228.0
# 1969-01-01  3.637159e+09                   2.077                75538692.0
# 1970-01-01  3.712698e+09                   2.091                77628719.0
# 1971-01-01  3.790326e+09                   2.011                76237935.0
# 1972-01-01  3.866564e+09                   1.953                75523025.0
# 1973-01-01  3.942087e+09                   1.890                74506117.0
# 1974-01-01  4.016594e+09                   1.779                71454588.0
# 1975-01-01  4.088048e+09                   1.714                70050152.0
# 1976-01-01  4.158098e+09                   1.702                70784413.0
# 1977-01-01  4.228883e+09                   1.675                70854118.0
# 1978-01-01  4.299737e+09                   1.714                73687278.0
# 1979-01-01  4.373424e+09                   1.625                71072677.0
# ...                  ...                     ...                       ...
# 2020-01-01  7.629798e+09                   0.972                74180649.0
# 2021-01-01  7.703979e+09                   0.948                73038117.0
# 2022-01-01  7.777017e+09                   0.925                71959921.0
# 2023-01-01  7.848977e+09                   0.902                70783338.0
# 2024-01-01  7.919760e+09                   0.878                69524853.0
# 2025-01-01  7.989285e+09                   0.855                68326213.0
# 2026-01-01  8.057611e+09                   0.834                67184329.0
# 2027-01-01  8.124796e+09                   0.812                65991012.0
# 2028-01-01  8.190787e+09                   0.791                64786039.0
# 2029-01-01  8.255573e+09                   0.770                63573707.0
# 2030-01-01  8.319146e+09                   0.751                62440399.0
# 2031-01-01  8.381587e+09                   0.732                61392910.0
# 2032-01-01  8.442980e+09                   0.715                60347733.0
# 2033-01-01  8.503327e+09                   0.697                59296566.0
# 2034-01-01  8.562624e+09                   0.680                58227334.0
# 2035-01-01  8.620851e+09                   0.664                57219349.0
# 2036-01-01  8.678071e+09                   0.648                56270154.0
# 2037-01-01  8.734341e+09                   0.633                55301550.0
# 2038-01-01  8.789642e+09                   0.618                54311392.0
# 2039-01-01  8.843954e+09                   0.603                53298659.0
# 2040-01-01  8.897252e+09                   0.588                52322446.0
# 2041-01-01  8.949575e+09                   0.574                51378065.0
# 2042-01-01  9.000953e+09                   0.560                50390602.0
# 2043-01-01  9.051343e+09                   0.545                49356913.0
# 2044-01-01  9.100700e+09                   0.531                48284246.0
# 2045-01-01  9.148985e+09                   0.516                47237518.0
# 2046-01-01  9.196222e+09                   0.502                46210494.0
# 2047-01-01  9.242433e+09                   0.488                45138181.0
# 2048-01-01  9.287571e+09                   0.474                44027603.0
# 2049-01-01  9.331598e+09                   0.460                42885822.0
#
# [100 rows x 3 columns]

# %%
pop_growth.resample('10AS').mean()
# Out:
#               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-01-01  2.765922e+09                  1.7529                48537285.4
# 1960-01-01  3.321900e+09                  2.0094                66969623.4
# 1970-01-01  4.047646e+09                  1.8154                73179902.2
# 1980-01-01  4.813578e+09                  1.7438                83875618.4
# 1990-01-01  5.651506e+09                  1.4220                80123197.0
# 2000-01-01  6.429734e+09                  1.2017                77213097.9
# 2010-01-01  7.206287e+09                  1.0742                77318221.4
# 2020-01-01  7.949758e+09                  0.8687                68934817.8
# 2030-01-01  8.587652e+09                  0.6741                57810604.6
# 2040-01-01  9.120663e+09                  0.5238                47723189.0

# %% [markdown]
# This kind of resampling is called _downsampling_, because we are decreasing the sampling frequency of the data. We can choose how to aggregate the data from each decade (e.g. `mean`). Options for aggregation include `mean`, `median`, `sum`, `last`, and `first`.
#
# We can also _upsample_ data. In this case, we don't have data for each quarter, so we have to tell Pandas has to fill in the missing data.

# %%
pop_growth.resample('1Q').bfill().head()
# Out:
#               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-03-31  2.594940e+09                   1.612                41832429.0
# 1950-06-30  2.594940e+09                   1.612                41832429.0
# 1950-09-30  2.594940e+09                   1.612                41832429.0
# 1950-12-31  2.594940e+09                   1.612                41832429.0
# 1951-03-31  2.636772e+09                   1.717                45281083.0

# %%
pop_growth.resample('1Q').ffill().head()
# Out:
#               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-03-31  2.557629e+09                   1.459                37311223.0
# 1950-06-30  2.557629e+09                   1.459                37311223.0
# 1950-09-30  2.557629e+09                   1.459                37311223.0
# 1950-12-31  2.557629e+09                   1.459                37311223.0
# 1951-03-31  2.594940e+09                   1.612                41832429.0

# %% [markdown]
# Pandas' time series capabilities are built on the Pandas `Timestamp` class.

# %%
print(pd.Timestamp('January 8, 2017'))
print(pd.Timestamp('01/08/17 20:13'))
print(pd.Timestamp(1.4839*10**18))
# Out:
# 2017-01-08 00:00:00
# 2017-01-08 20:13:00
# 2017-01-08 18:26:40

# %%
print(pd.Timestamp('Feb. 11 2016 2:30 am') - pd.Timestamp('2015-08-03 5:14 pm'))
# Out:
# 191 days 09:16:00

# %%
from pandas.tseries.offsets import BDay, Day, BMonthEnd

print(pd.Timestamp('January 9, 2017') - Day(4))
print(pd.Timestamp('January 9, 2017') - BDay(4))
print(pd.Timestamp('January 9, 2017') + BMonthEnd(4))
# Out:
# 2017-01-05 00:00:00
# 2017-01-03 00:00:00
# 2017-04-28 00:00:00

# %% [markdown]
# If we're entering time series data into a DataFrame it will often be useful to create a range of dates.

# %%
pd.date_range(start='1/8/2017', end='3/2/2017', freq='B')
# Out:
# DatetimeIndex(['2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-16', '2017-01-17', '2017-01-18',
#                '2017-01-19', '2017-01-20', '2017-01-23', '2017-01-24',
#                '2017-01-25', '2017-01-26', '2017-01-27', '2017-01-30',
#                '2017-01-31', '2017-02-01', '2017-02-02', '2017-02-03',
#                '2017-02-06', '2017-02-07', '2017-02-08', '2017-02-09',
#                '2017-02-10', '2017-02-13', '2017-02-14', '2017-02-15',
#                '2017-02-16', '2017-02-17', '2017-02-20', '2017-02-21',
#                '2017-02-22', '2017-02-23', '2017-02-24', '2017-02-27',
#                '2017-02-28', '2017-03-01', '2017-03-02'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# The `Timestamp` class is compatible with Python's `datetime` module.

# %%
import datetime

pd.Timestamp('May 1, 2017') - datetime.datetime(2017, 1, 8)
# Out:
# Timedelta('113 days 00:00:00')

# %% [markdown]
# ## Visualizing data with Pandas
#
# Visualizing a data set is an important first step in drawing insights. We can easily pass data from Pandas to Matplotlib for visualizations, but Pandas also plugs into Matplotlib directly through methods like `plot` and `hist`.

# %%
yelp_df['review_count'].apply(np.log).hist(bins=30)

# %%
pop_growth['Annual Growth Rate (%)'].plot()

# %% [markdown]
# The [plotting functions take many parameters](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) for customizing the appearance of the output. Since they are essentially a wrapper around the Matplotlib functions, they also accept many of the Matplotlib parameters, not all of which are listed in the Pandas documentation. Pandas provides [a guide](https://pandas.pydata.org/pandas-docs/stable/visualization.html) to making various plots from DataFrames.

# %% [markdown]
# *Copyright &copy; 2017 The Data Incubator.  All rights reserved.*
